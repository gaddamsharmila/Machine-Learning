# %% [markdown]
# ***My first program***

# %%
print(" Iam Sharmila")
# Out:
#  Iam Sharmila

# %% [markdown]
# **Variable declaration in pyhton**

# %%
a=5
b=9
sum=a+b
print(sum)
print("sum")
# Out:
# 14
# sum

# %% [markdown]
# Subtraction

# %%
a=100
b=200
c=150
sub=a-b-c
print("sub")
print(sub)
# Out:
# sub
# -250

# %% [markdown]
# Multiplication

# %%
a=24
b=89
mul=a*b
print("mul")
print(mul)
# Out:
# mul
# 2136

# %% [markdown]
# Divion (quotient and remainder)

# %%
a=12
b=6
quotient=a//b
remainder=a%b
print("quotient")
print(quotient)
print("remainder")
print(remainder)
# Out:
# quotient
# 2
# remainder
# 0

# %% [markdown]
# Squaring of number

# %%
a=76
squ=a**2
print("squ")
print(squ)
# Out:
# squ
# 5776

# %% [markdown]
# Square root

# %%
import math
math.sqrt(54)
# Out:
# 7.3484692283495345

# %% [markdown]
# cubing

# %%
a=100
b=3
print(a**b)
# Out:
# 1000000
