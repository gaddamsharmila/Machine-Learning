# %% [markdown]
# Data Types

# %%
name="sharmila"
print(type(name))
# Out:
# <class 'str'>

# %%
 name1="sharmila % 1234"
 print(type(name1))
# Out:
# <class 'str'>

# %% [markdown]
# Sequence Data Types

# %%
list=['sha','123','56.8']
type(list)
# Out:
# list

# %%
list1=['apple','200','person']
print(len(list))
print(len(list1))
list3=list+list1
print(len(list3))
# Out:
# 3
# 3
# 6

# %%
list1.append("xyz")

# %%
list1
# Out:
# ['apple', '200', 'person', 'xyz']

# %%
list1.clear()

# %%
list1
# Out:
# []

# %%
lis=['djcb','123','kle']
lis[0]
# Out:
# 'djcb'

# %%
lis.sort()

# %%
lis
# Out:
# ['123', 'djcb', 'kle']

# %% [markdown]
# tupes

# %%
tuple1=("sharmila","hubballi","bellari","sharmila")
print(type(tuple1))
tuple2=("sharmila")
print(type(tuple2))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
tuple1=("sharmila","hubballi","bellari","sharmila")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[-1])
tuple6=tuple1+tuple1
print(tuple6)
tuple7=tuple6*2
print(tuple7)

y=tuple7.index('bellari')
print(y)

x=tuple7.count('hubli')
print(x)
# Out:
# sharmila
# hubballi
# bellari
# sharmila
# ('sharmila', 'hubballi', 'bellari', 'sharmila', 'sharmila', 'hubballi', 'bellari', 'sharmila')
# ('sharmila', 'hubballi', 'bellari', 'sharmila', 'sharmila', 'hubballi', 'bellari', 'sharmila', 'sharmila', 'hubballi', 'bellari', 'sharmila', 'sharmila', 'hubballi', 'bellari', 'sharmila')
# 2
# 0

# %%
x=("hubli","belgam","banglore")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
y[2]="mumbai"
x=tuple(y)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f476ef54a992> in <cell line: 1>()
# ----> 1 y=list(x)
#       2 y[2]="mumbai"
#       3 x=tuple(y)
#       4 print(x)
#
# NameError: name 'x' is not defined

# %%
x=("hubli","belgam","banglore")

# %% [markdown]
# 1) Declaring and assigning variables

# %%
#CHECK IF THE FIRST AND LAST ELEMENTS OF THE LIST ARE SAME
list=[15,2,3,2,17]
print("The list will be",list)
f=list[0]
print("First element",f)
l=list[-1]
print("last element",l)
if(f==l):
  print("True")

else:
  print("False")
# Out:
# The list will be [15, 2, 3, 2, 17]
# First element 15
# last element 17
# False

# %%
#DISPLAY NUMBERS DIVISIBLE BY 5 FROM THE LIST
num_list = [10, 20, 33, 46, 55]
print("Given list:", num_list)
print("Divisible by 5:")
for num in num_list:
    if num % 5 == 0:
        print(num)#
# Out:
# Given list: [10, 20, 33, 46, 55]
# Divisible by 5:
# 10
# 20
# 55

# %%
#.DISPLAY IF THE GIVEN NUMBER IS EVEN OR ODD
x=(int(input("Enter the number.")))
if x % 2 ==0:
  print(x,"is even")

else:
  print(x,"is odd")
# Out:
# Enter the number.20
# 20 is even

# %%
#.PRINT THE SUM OF CURRENT AND PREVIOUS NUMBERS
print("Printing current and previous number and their sum in a range (10)")
previous_num=0
for i in range(1,11):
  sum=previous_num+i
  print("Current number",i,"previous number",previous_num,"Sum:",sum)
  previous_num=i
# Out:
# Printing current and previous number and their sum in a range (10)
# Current number 1 previous number 0 Sum: 1
# Current number 2 previous number 1 Sum: 3
# Current number 3 previous number 2 Sum: 5
# Current number 4 previous number 3 Sum: 7
# Current number 5 previous number 4 Sum: 9
# Current number 6 previous number 5 Sum: 11
# Current number 7 previous number 6 Sum: 13
# Current number 8 previous number 7 Sum: 15
# Current number 9 previous number 8 Sum: 17
# Current number 10 previous number 9 Sum: 19

# %%
#PRINT THE CHARACTERS FROM THE STRING AT EVEN INDEX
word=input("enter word: ")
print("Original string",word)
size=len(word)
print("Printing only even index characters")
for i in range(0,size-1,2):
  print("index[",i,"]",word[i])
# Out:
# enter word: A
# Original string A
# Printing only even index characters
